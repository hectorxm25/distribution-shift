# %%
import nnsight
from nnsight import NNsight
import torch

from robustness import model_utils
from robustness.datasets import CIFAR

import torchvision.transforms as transforms
from PIL import Image

import os
import sys
# Add the parent directory to the path to import custom modules
sys.path.append(os.path.abspath(os.path.join('..')))
from models.resnet import ResNet18
# Out:
# 2025-04-04 13:51:19.379761: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# load saved model
datapath = '/u/yshi23/distribution-shift/datasets'
model_pth = "/u/yshi23/distribution-shift/adversarial/out/checkpoint.pt.best"
device = "cpu"

# model init using robustness mechanism
# model, _ = model_utils.make_and_restore_model(
#     arch='resnet18', dataset=CIFAR(datapath), resume_path=model_pth, device=device
# )
# Load the checkpoint with map_location to ensure it's on the right device
model = ResNet18(num_classes=10)
checkpoint = torch.load(model_pth, map_location=device)

# Get the state dict
state_dict = checkpoint["model"]

# Create a new state dict with properly formatted keys
new_state_dict = {}
for k, v in state_dict.items():
    # Remove 'module.' prefix if present
    if k.startswith('module.'):
        print("Removing 'module.' prefix from key:", k)
        name = k[7:]  # remove 'module.'
    else:
        name = k
    new_state_dict[name] = v

# Load the modified state dict with strict=False to ignore missing/unexpected keys
model.load_state_dict(new_state_dict, strict=False)

print("Model loaded successfully on", device)
# Out:
# Removing 'module.' prefix from key: module.normalizer.new_mean
# Removing 'module.' prefix from key: module.normalizer.new_std
# Removing 'module.' prefix from key: module.model.conv1.weight
# Removing 'module.' prefix from key: module.model.bn1.weight
# Removing 'module.' prefix from key: module.model.bn1.bias
# Removing 'module.' prefix from key: module.model.bn1.running_mean
# Removing 'module.' prefix from key: module.model.bn1.running_var
# Removing 'module.' prefix from key: module.model.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer1.0.conv1.weight
# Removing 'module.' prefix from key: module.model.layer1.0.bn1.weight
# Removing 'module.' prefix from key: module.model.layer1.0.bn1.bias
# Removing 'module.' prefix from key: module.model.layer1.0.bn1.running_mean
# Removing 'module.' prefix from key: module.model.layer1.0.bn1.running_var
# Removing 'module.' prefix from key: module.model.layer1.0.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer1.0.conv2.weight
# Removing 'module.' prefix from key: module.model.layer1.0.bn2.weight
# Removing 'module.' prefix from key: module.model.layer1.0.bn2.bias
# Removing 'module.' prefix from key: module.model.layer1.0.bn2.running_mean
# Removing 'module.' prefix from key: module.model.layer1.0.bn2.running_var
# Removing 'module.' prefix from key: module.model.layer1.0.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer1.1.conv1.weight
# Removing 'module.' prefix from key: module.model.layer1.1.bn1.weight
# Removing 'module.' prefix from key: module.model.layer1.1.bn1.bias
# Removing 'module.' prefix from key: module.model.layer1.1.bn1.running_mean
# Removing 'module.' prefix from key: module.model.layer1.1.bn1.running_var
# Removing 'module.' prefix from key: module.model.layer1.1.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer1.1.conv2.weight
# Removing 'module.' prefix from key: module.model.layer1.1.bn2.weight
# Removing 'module.' prefix from key: module.model.layer1.1.bn2.bias
# Removing 'module.' prefix from key: module.model.layer1.1.bn2.running_mean
# Removing 'module.' prefix from key: module.model.layer1.1.bn2.running_var
# Removing 'module.' prefix from key: module.model.layer1.1.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer2.0.conv1.weight
# Removing 'module.' prefix from key: module.model.layer2.0.bn1.weight
# Removing 'module.' prefix from key: module.model.layer2.0.bn1.bias
# Removing 'module.' prefix from key: module.model.layer2.0.bn1.running_mean
# Removing 'module.' prefix from key: module.model.layer2.0.bn1.running_var
# Removing 'module.' prefix from key: module.model.layer2.0.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer2.0.conv2.weight
# Removing 'module.' prefix from key: module.model.layer2.0.bn2.weight
# Removing 'module.' prefix from key: module.model.layer2.0.bn2.bias
# Removing 'module.' prefix from key: module.model.layer2.0.bn2.running_mean
# Removing 'module.' prefix from key: module.model.layer2.0.bn2.running_var
# Removing 'module.' prefix from key: module.model.layer2.0.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer2.0.shortcut.0.weight
# Removing 'module.' prefix from key: module.model.layer2.0.shortcut.1.weight
# Removing 'module.' prefix from key: module.model.layer2.0.shortcut.1.bias
# Removing 'module.' prefix from key: module.model.layer2.0.shortcut.1.running_mean
# Removing 'module.' prefix from key: module.model.layer2.0.shortcut.1.running_var
# Removing 'module.' prefix from key: module.model.layer2.0.shortcut.1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer2.1.conv1.weight
# Removing 'module.' prefix from key: module.model.layer2.1.bn1.weight
# Removing 'module.' prefix from key: module.model.layer2.1.bn1.bias
# Removing 'module.' prefix from key: module.model.layer2.1.bn1.running_mean
# Removing 'module.' prefix from key: module.model.layer2.1.bn1.running_var
# Removing 'module.' prefix from key: module.model.layer2.1.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer2.1.conv2.weight
# Removing 'module.' prefix from key: module.model.layer2.1.bn2.weight
# Removing 'module.' prefix from key: module.model.layer2.1.bn2.bias
# Removing 'module.' prefix from key: module.model.layer2.1.bn2.running_mean
# Removing 'module.' prefix from key: module.model.layer2.1.bn2.running_var
# Removing 'module.' prefix from key: module.model.layer2.1.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer3.0.conv1.weight
# Removing 'module.' prefix from key: module.model.layer3.0.bn1.weight
# Removing 'module.' prefix from key: module.model.layer3.0.bn1.bias
# Removing 'module.' prefix from key: module.model.layer3.0.bn1.running_mean
# Removing 'module.' prefix from key: module.model.layer3.0.bn1.running_var
# Removing 'module.' prefix from key: module.model.layer3.0.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer3.0.conv2.weight
# Removing 'module.' prefix from key: module.model.layer3.0.bn2.weight
# Removing 'module.' prefix from key: module.model.layer3.0.bn2.bias
# Removing 'module.' prefix from key: module.model.layer3.0.bn2.running_mean
# Removing 'module.' prefix from key: module.model.layer3.0.bn2.running_var
# Removing 'module.' prefix from key: module.model.layer3.0.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer3.0.shortcut.0.weight
# Removing 'module.' prefix from key: module.model.layer3.0.shortcut.1.weight
# Removing 'module.' prefix from key: module.model.layer3.0.shortcut.1.bias
# Removing 'module.' prefix from key: module.model.layer3.0.shortcut.1.running_mean
# Removing 'module.' prefix from key: module.model.layer3.0.shortcut.1.running_var
# Removing 'module.' prefix from key: module.model.layer3.0.shortcut.1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer3.1.conv1.weight
# Removing 'module.' prefix from key: module.model.layer3.1.bn1.weight
# Removing 'module.' prefix from key: module.model.layer3.1.bn1.bias
# Removing 'module.' prefix from key: module.model.layer3.1.bn1.running_mean
# Removing 'module.' prefix from key: module.model.layer3.1.bn1.running_var
# Removing 'module.' prefix from key: module.model.layer3.1.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer3.1.conv2.weight
# Removing 'module.' prefix from key: module.model.layer3.1.bn2.weight
# Removing 'module.' prefix from key: module.model.layer3.1.bn2.bias
# Removing 'module.' prefix from key: module.model.layer3.1.bn2.running_mean
# Removing 'module.' prefix from key: module.model.layer3.1.bn2.running_var
# Removing 'module.' prefix from key: module.model.layer3.1.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer4.0.conv1.weight
# Removing 'module.' prefix from key: module.model.layer4.0.bn1.weight
# Removing 'module.' prefix from key: module.model.layer4.0.bn1.bias
# Removing 'module.' prefix from key: module.model.layer4.0.bn1.running_mean
# Removing 'module.' prefix from key: module.model.layer4.0.bn1.running_var
# Removing 'module.' prefix from key: module.model.layer4.0.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer4.0.conv2.weight
# Removing 'module.' prefix from key: module.model.layer4.0.bn2.weight
# Removing 'module.' prefix from key: module.model.layer4.0.bn2.bias
# Removing 'module.' prefix from key: module.model.layer4.0.bn2.running_mean
# Removing 'module.' prefix from key: module.model.layer4.0.bn2.running_var
# Removing 'module.' prefix from key: module.model.layer4.0.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer4.0.shortcut.0.weight
# Removing 'module.' prefix from key: module.model.layer4.0.shortcut.1.weight
# Removing 'module.' prefix from key: module.model.layer4.0.shortcut.1.bias
# Removing 'module.' prefix from key: module.model.layer4.0.shortcut.1.running_mean
# Removing 'module.' prefix from key: module.model.layer4.0.shortcut.1.running_var
# Removing 'module.' prefix from key: module.model.layer4.0.shortcut.1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer4.1.conv1.weight
# Removing 'module.' prefix from key: module.model.layer4.1.bn1.weight
# Removing 'module.' prefix from key: module.model.layer4.1.bn1.bias
# Removing 'module.' prefix from key: module.model.layer4.1.bn1.running_mean
# Removing 'module.' prefix from key: module.model.layer4.1.bn1.running_var
# Removing 'module.' prefix from key: module.model.layer4.1.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.model.layer4.1.conv2.weight
# Removing 'module.' prefix from key: module.model.layer4.1.bn2.weight
# Removing 'module.' prefix from key: module.model.layer4.1.bn2.bias
# Removing 'module.' prefix from key: module.model.layer4.1.bn2.running_mean
# Removing 'module.' prefix from key: module.model.layer4.1.bn2.running_var
# Removing 'module.' prefix from key: module.model.layer4.1.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.model.linear.weight
# Removing 'module.' prefix from key: module.model.linear.bias
# Removing 'module.' prefix from key: module.attacker.normalize.new_mean
# Removing 'module.' prefix from key: module.attacker.normalize.new_std
# Removing 'module.' prefix from key: module.attacker.model.conv1.weight
# Removing 'module.' prefix from key: module.attacker.model.bn1.weight
# Removing 'module.' prefix from key: module.attacker.model.bn1.bias
# Removing 'module.' prefix from key: module.attacker.model.bn1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.bn1.running_var
# Removing 'module.' prefix from key: module.attacker.model.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.conv1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.bn1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.bn1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.bn1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.bn1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.conv2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.bn2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.bn2.bias
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.bn2.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.bn2.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer1.0.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.conv1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.bn1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.bn1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.bn1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.bn1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.conv2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.bn2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.bn2.bias
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.bn2.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.bn2.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer1.1.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.conv1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.bn1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.bn1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.bn1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.bn1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.conv2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.bn2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.bn2.bias
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.bn2.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.bn2.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.shortcut.0.weight
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.shortcut.1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.shortcut.1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.shortcut.1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.shortcut.1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer2.0.shortcut.1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.conv1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.bn1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.bn1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.bn1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.bn1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.conv2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.bn2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.bn2.bias
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.bn2.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.bn2.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer2.1.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.conv1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.bn1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.bn1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.bn1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.bn1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.conv2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.bn2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.bn2.bias
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.bn2.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.bn2.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.shortcut.0.weight
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.shortcut.1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.shortcut.1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.shortcut.1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.shortcut.1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer3.0.shortcut.1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.conv1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.bn1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.bn1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.bn1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.bn1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.conv2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.bn2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.bn2.bias
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.bn2.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.bn2.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer3.1.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.conv1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.bn1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.bn1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.bn1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.bn1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.conv2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.bn2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.bn2.bias
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.bn2.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.bn2.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.shortcut.0.weight
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.shortcut.1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.shortcut.1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.shortcut.1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.shortcut.1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer4.0.shortcut.1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.conv1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.bn1.weight
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.bn1.bias
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.bn1.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.bn1.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.bn1.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.conv2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.bn2.weight
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.bn2.bias
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.bn2.running_mean
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.bn2.running_var
# Removing 'module.' prefix from key: module.attacker.model.layer4.1.bn2.num_batches_tracked
# Removing 'module.' prefix from key: module.attacker.model.linear.weight
# Removing 'module.' prefix from key: module.attacker.model.linear.bias
# Model loaded successfully on cpu

# %%
def load_cifar10_image(image_path):
    # Load the image
    img = Image.open(image_path)
    
    # Define the transforms that match ResNet18 expectations
    # ResNet18 expects 224x224 images, but CIFAR-10 is 32x32
    # We'll resize and normalize according to ImageNet stats as typically used with ResNet
    transform = transforms.Compose([
        transforms.Resize(32),  # Resize to 224x224
        transforms.ToTensor(),   # Convert to tensor
        transforms.Normalize(          # Normalize with CIFAR-10 stats
            mean=[0.4914, 0.4822, 0.4465],
            std=[0.2470, 0.2435, 0.2616]
        )
    ])
    
    # Apply transformations
    img_tensor = transform(img)
    
    # Add batch dimension
    img_tensor = img_tensor.unsqueeze(0)  # Shape: [1, 3, 224, 224]
    
    return img_tensor

# Usage example
image_path = "inputs/adv_image_small_epsilon_5.png"
img_tensor = load_cifar10_image(image_path)

# %%
# Get all layer names (keys) from the model's state dictionary
layer_names = list(model.state_dict().keys())

# Print all layer names
print("Model layer names:")
for name in layer_names:
    print(name)

# Optionally, to save the list to a file
with open('model_layer_names.txt', 'w') as f:
    for name in layer_names:
        if "attacker" not in name: # filter out attacker layers
            f.write(name + '\n')
# Out:
# Model layer names:
# conv1.weight
# bn1.weight
# bn1.bias
# bn1.running_mean
# bn1.running_var
# bn1.num_batches_tracked
# layer1.0.conv1.weight
# layer1.0.bn1.weight
# layer1.0.bn1.bias
# layer1.0.bn1.running_mean
# layer1.0.bn1.running_var
# layer1.0.bn1.num_batches_tracked
# layer1.0.conv2.weight
# layer1.0.bn2.weight
# layer1.0.bn2.bias
# layer1.0.bn2.running_mean
# layer1.0.bn2.running_var
# layer1.0.bn2.num_batches_tracked
# layer1.1.conv1.weight
# layer1.1.bn1.weight
# layer1.1.bn1.bias
# layer1.1.bn1.running_mean
# layer1.1.bn1.running_var
# layer1.1.bn1.num_batches_tracked
# layer1.1.conv2.weight
# layer1.1.bn2.weight
# layer1.1.bn2.bias
# layer1.1.bn2.running_mean
# layer1.1.bn2.running_var
# layer1.1.bn2.num_batches_tracked
# layer2.0.conv1.weight
# layer2.0.bn1.weight
# layer2.0.bn1.bias
# layer2.0.bn1.running_mean
# layer2.0.bn1.running_var
# layer2.0.bn1.num_batches_tracked
# layer2.0.conv2.weight
# layer2.0.bn2.weight
# layer2.0.bn2.bias
# layer2.0.bn2.running_mean
# layer2.0.bn2.running_var
# layer2.0.bn2.num_batches_tracked
# layer2.0.shortcut.0.weight
# layer2.0.shortcut.1.weight
# layer2.0.shortcut.1.bias
# layer2.0.shortcut.1.running_mean
# layer2.0.shortcut.1.running_var
# layer2.0.shortcut.1.num_batches_tracked
# layer2.1.conv1.weight
# layer2.1.bn1.weight
# layer2.1.bn1.bias
# layer2.1.bn1.running_mean
# layer2.1.bn1.running_var
# layer2.1.bn1.num_batches_tracked
# layer2.1.conv2.weight
# layer2.1.bn2.weight
# layer2.1.bn2.bias
# layer2.1.bn2.running_mean
# layer2.1.bn2.running_var
# layer2.1.bn2.num_batches_tracked
# layer3.0.conv1.weight
# layer3.0.bn1.weight
# layer3.0.bn1.bias
# layer3.0.bn1.running_mean
# layer3.0.bn1.running_var
# layer3.0.bn1.num_batches_tracked
# layer3.0.conv2.weight
# layer3.0.bn2.weight
# layer3.0.bn2.bias
# layer3.0.bn2.running_mean
# layer3.0.bn2.running_var
# layer3.0.bn2.num_batches_tracked
# layer3.0.shortcut.0.weight
# layer3.0.shortcut.1.weight
# layer3.0.shortcut.1.bias
# layer3.0.shortcut.1.running_mean
# layer3.0.shortcut.1.running_var
# layer3.0.shortcut.1.num_batches_tracked
# layer3.1.conv1.weight
# layer3.1.bn1.weight
# layer3.1.bn1.bias
# layer3.1.bn1.running_mean
# layer3.1.bn1.running_var
# layer3.1.bn1.num_batches_tracked
# layer3.1.conv2.weight
# layer3.1.bn2.weight
# layer3.1.bn2.bias
# layer3.1.bn2.running_mean
# layer3.1.bn2.running_var
# layer3.1.bn2.num_batches_tracked
# layer4.0.conv1.weight
# layer4.0.bn1.weight
# layer4.0.bn1.bias
# layer4.0.bn1.running_mean
# layer4.0.bn1.running_var
# layer4.0.bn1.num_batches_tracked
# layer4.0.conv2.weight
# layer4.0.bn2.weight
# layer4.0.bn2.bias
# layer4.0.bn2.running_mean
# layer4.0.bn2.running_var
# layer4.0.bn2.num_batches_tracked
# layer4.0.shortcut.0.weight
# layer4.0.shortcut.1.weight
# layer4.0.shortcut.1.bias
# layer4.0.shortcut.1.running_mean
# layer4.0.shortcut.1.running_var
# layer4.0.shortcut.1.num_batches_tracked
# layer4.1.conv1.weight
# layer4.1.bn1.weight
# layer4.1.bn1.bias
# layer4.1.bn1.running_mean
# layer4.1.bn1.running_var
# layer4.1.bn1.num_batches_tracked
# layer4.1.conv2.weight
# layer4.1.bn2.weight
# layer4.1.bn2.bias
# layer4.1.bn2.running_mean
# layer4.1.bn2.running_var
# layer4.1.bn2.num_batches_tracked
# linear.weight
# linear.bias

# %%
nnsight_model = NNsight(model)
print(nnsight_model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
with nnsight_model.trace(img_tensor) as tracer:
    # Forward pass through the model

    conv1_out = nnsight_model.conv1.output.save()
    layer1_out = nnsight_model.layer1.output.save()
    layer2_out = nnsight_model.layer2.output.save()
    layer3_out = nnsight_model.layer3.output.save()
    layer4_out = nnsight_model.layer4.output.save()
    linear_out = nnsight_model.linear.output.save()


print(conv1_out.shape)
print(layer1_out.shape)
print(layer2_out.shape)
print(layer3_out.shape)
print(layer4_out.shape)
print(linear_out.shape)
# Out:
# torch.Size([1, 64, 32, 32])
# torch.Size([1, 64, 32, 32])
# torch.Size([1, 128, 16, 16])
# torch.Size([1, 256, 8, 8])
# torch.Size([1, 512, 4, 4])
# torch.Size([1, 10])

# %%
out = model(img_tensor)
# Out:
# (tensor([[ 0.0128, -0.1825,  0.2957,  0.2169,  0.1169,  0.0109, -0.2548,  0.1310,
#           -0.2498, -0.0975]], grad_fn=<AddmmBackward0>),
#  tensor([[[[ 1.9638,  1.9162,  1.7257,  ...,  1.1224,  1.1065,  1.2494],
#            [ 1.9956,  1.8051,  1.9321,  ...,  1.3129,  1.3129,  1.2176],
#            [ 1.9956,  1.8845,  1.8210,  ...,  1.1859,  1.1541,  1.3764],
#            ...,
#            [-1.3703, -1.4338, -1.4655,  ..., -1.4655, -1.1639, -1.2274],
#            [-1.1321, -1.2433, -1.2115,  ..., -1.3544, -1.3226, -1.2115],
#            [-1.1163, -1.3703, -1.0845,  ..., -0.9416, -1.1163, -0.9416]],
#
#           [[ 1.8205,  1.7722,  1.9171,  ...,  1.2407,  1.0475,  1.1119],
#            [ 1.8527,  1.8366,  2.0460,  ...,  1.3534,  1.3051,  1.2890],
#            [ 2.1104,  1.9171,  1.8527,  ...,  1.1763,  1.4018,  1.5145],
#            ...,
#            [-1.3361, -1.4810, -1.3039,  ..., -1.4810, -1.1267, -1.1750],
#            [-1.2556, -1.3683, -1.2556,  ..., -1.2878, -1.3200, -1.2878],
#            [-1.2556, -1.4005, -1.1750,  ..., -1.0462, -1.1750, -1.0784]],
#
#           [[ 1.9359,  1.9359,  1.9809,  ...,  1.5912,  1.5312,  1.5912],
#            [ 2.0109,  1.9060,  2.1158,  ...,  1.7111,  1.6361,  1.7411],
#            [ 2.0709,  2.0709,  2.0409,  ...,  1.6211,  1.6511,  1.8160],
#            ...,
#            [-0.9423, -1.1821, -1.0622,  ..., -1.4670, -1.1821, -1.3620],
#            [-0.8823, -1.1222, -1.0322,  ..., -1.3770, -1.3770, -1.4220],
#            [-0.8523, -1.1671, -0.9423,  ..., -1.1671, -1.2721, -1.1821]]]]))
